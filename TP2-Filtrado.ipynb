# %% [markdown]
# ## <img src="./fiuba.jpg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 2
# #### Ericson Joseph Estupiñan Pineda
#
# ***
# ## Filtrado

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
#  $$ y(k) = \frac{1}{N} \sum_{i=0}^{N-1} x(k-i)  $$
#
#  Para N = [3; 5]

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./ej1img3.jpg" align="center" width="50%" />
# <img src="./ej1img2.jpg" align="center" width="50%" />
# <img src="./ej1img1.jpg" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante la simulación computacional

# %%
## Inicialización del Notebook del TP4

import numpy as np
from pandas import DataFrame
from IPython.display import HTML
from scipy import signal as sig

# %run plot_zplane.py

# Insertar aquí el código para inicializar tu notebook
########################################################

import matplotlib as mpl
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

import matplotlib.pyplot as plt

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

def vertical_flaten(a):
    
    return a.reshape(a.shape[0],1)

# %%
A = [[1/3, 1/3, 1/3, 0,   0],
     [1/4, 1/4, 1/4, 1/4, 0],
     [1/5, 1/5, 1/5, 1/5, 1/5]]

# N = 3
print("#######################################")
print("################ N = 3 ################")
print("#######################################")
ww, hh = sig.freqz(np.array(A[0]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N=3')

plt.title('FIR N = 3')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = A[0];
b = [1, 0, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR N = 3')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()

# N = 4
print("#######################################")
print("################ N = 4 ################")
print("#######################################")
ww, hh = sig.freqz(np.array(A[1]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N=4')

plt.title('FIR N = 4')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

# %run plot_zplane.py
a = [1, 1, 1, 1, 0];
b = [1, 0, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR N = 4')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()

# N = 5
print("#######################################")
print("################ N = 5 ################")
print("#######################################")
ww, hh = sig.freqz(np.array(A[2]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N=5')

plt.title('FIR N = 5')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = [1, 1, 1, 1, 1];
b = [1, 0, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR N = 5')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()
# Out:
# #######################################
# ################ N = 3 ################
# #######################################
# /home/ericson/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Ubuntu'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# #######################################
# ################ N = 4 ################
# #######################################
# /home/ericson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: RuntimeWarning: divide by zero encountered in log10
# #######################################
# ################ N = 5 ################
# #######################################

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# $$ h(k) = (-1, 1) $$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./ej2img1.jpg" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
ww, hh = sig.freqz(np.array([-1,1]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='Ejercicio 2')

plt.title('FIR Ejercicio 2')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = [-1,1];
b = [1, 0, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR Ejercicio 2')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()
# Out:
# /home/ericson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# <img src="./comb.png" align="center" width="30%" />
#
#
# Para $N= (2; 4)$ y $b = -1$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./ej3img4.jpg" align="center" width="50%" />
# <img src="./ej3img3.jpg" align="center" width="50%" />
# <img src="./ej3img2.jpg" align="center" width="50%" />
# <img src="./ej3img1.jpg" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
#  N = 2                                 #
##########################################

print("#######################################")
print("################ N = 2 ################")
print("#######################################")
ww, hh = sig.freqz(np.array([-1, 0, 1]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N 2')

plt.title('FIR Ejercicio 3 N = 2')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = [-1, 0, 1];
b = [1, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR Ejercicio 3 N = 2')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()

##########################################
#  N = 3                                 #
##########################################
print("#######################################")
print("################ N = 3 ################")
print("#######################################")
ww, hh = sig.freqz(np.array([-1, 0, 0, 1]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N = 3')

plt.title('FIR Ejercicio 3 N = 3')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = [-1, 0, 0, 1];
b = [1, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR Ejercicio 3 N = 3')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()

##########################################
#  N = 4                                 #
##########################################
print("#######################################")
print("################ N = 4 ################")
print("#######################################")
ww, hh = sig.freqz(np.array([-1, 0, 0, 0, 1]), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='N = 4')

plt.title('FIR Ejercicio 3 N = 4')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

a = [-1, 0, 0, 0, 1];
b = [1, 0, 0, 0, 0];
zplane(a, b);

angles = np.unwrap(np.angle(hh))
plt.plot(ww, angles, 'g')
plt.title('FIR Ejercicio 3 N = 4')
plt.ylabel('Angle (radians)', color='g')
plt.grid()
plt.axis('tight')
plt.show()
# Out:
# #######################################
# ################ N = 2 ################
# #######################################
# /home/ericson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':
# #######################################
# ################ N = 3 ################
# #######################################
# /home/ericson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log10
# #######################################
# ################ N = 4 ################
# #######################################
# /home/ericson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:76: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> En el archivo <i>ECG_TP4.mat</i> encontrará un registro electrocardiográfico (ECG) registrado durante una prueba de esfuerzo, junto con una serie de variables descriptas a continuación. Diseñe y aplique los filtros digitales necesarios para mitigar las siguientes fuentes de contaminación:
# </div>

# %% [markdown]
#  - Ruido causado por el movimiento de los electrodos (Alta frecuencia)
#  - Ruido muscular (Alta frecuencia)
#  - Movimiento de la línea de base del ECG, inducido en parte por la respiración (Baja frecuencia)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Los latidos presentes en el registro de ECG, alineados y clasificados (de origen normal y ventricular) poseen las siguientes características temporales y frecuenciales:
# </div>

# %% [markdown]
# <img src="./latidos_tiempo.png" align="center" width="80%" />
#
# <img src="./latido_promedio.png" align="center" width="80%" />
#
# <img src="./latidos_espectro.png" align="center" width="80%" />

# %% [markdown]
# ### Archivo *ECG_TP4.mat*
# (variables)
#  - **ecg_lead**: Registro de ECG muestreado a $fs=1$ KHz durante una prueba de esfuerzo
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular
#  - **qrs_detections**: vector con las localizaciones (en # de muestras) donde ocurren los latidos
#
# a) Establezca una plantilla de diseño para los filtros digitales que necesitará para que la señal de ECG se asemeje a los latidos promedio en cuanto a *suavidad* de los trazos y nivel isoeléctrico nulo.

# %%
# Defina la plantilla del filtro

fs0 = 80 # fin de la banda de detenida 0
fc0 = 1 # comienzo de la banda de paso
fc1 = 45 # fin de la banda de paso
fs1 = 45 # comienzo de la banda de detenida 1

# %% [markdown]
# b) ¿Cómo obtuvo dichos valores?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Se reviso la grafica de espectro y se considero las frecuencias superiores a 0.2 de la amplitud normalizada, ademas no se tienen en cuenta bajas frecuencias inferiores a 1 Hz.
# </div>

# %% [markdown]
# c) Diseñe **al menos** dos filtros FIR y dos IIR para su comparación. Verifique que la respuesta en frecuencia responda a la plantilla de diseño

# %%
import scipy.io as spio
from scipy import signal
from scipy.fftpack import fft

mat = spio.loadmat('ECG_TP4.mat', squeeze_me=True)

ecg_signal = mat['ecg_lead'];
ecg_signal = ecg_signal[100:2000]

Fs = 1000;
ts = 1/Fs
N = 1901

print("Espectro de la señal")

yf = fft(ecg_signal)
xf = np.linspace(0.0, 1.0/(2.0*ts), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

## FILTRO FIR 1
## Usando la herramienta pyFDA y teniendo en cuenta que se quiere
## conservar la morfologia de la señal, se diseño un filtro FIR
## con el metodo Equiripple.

Fs  = 1000  # 1 KHz
Fpb = 0.001 # 1 Hz
Fsb = 0.045 # 45 Hz
Apb = 0.5   # dB
Asb = 30    # dB

# Número de polos y ceros 26
a = [0.031056987747076294,
0.016047995640571265,
0.01970590344466803,
0.02354975906142587,
0.027436026437950713,
0.03132590313247768,
0.03508948437723199,
0.03861680035112385,
0.041790798145133465,
0.04453504073177333,
0.046766465642252376,
0.04842676049497416,
0.049448041950943836,
0.049796476116217014,
0.049448041950943836,
0.04842676049497416,
0.046766465642252376,
0.04453504073177333,
0.041790798145133465,
0.03861680035112385,
0.03508948437723199,
0.03132590313247768,
0.027436026437950713,
0.02354975906142587,
0.01970590344466803,
0.016047995640571265,
0.031056987747076294]

b = np.zeros(len(a))
b[0] = 1

ww, hh = sig.freqz(np.array(a), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='FIR')

plt.title('Filtro FIR 1')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

filtered_ecg = signal.filtfilt(a,b,ecg_signal)
plt.plot(ecg_signal, 'k-', label='ecg_signal')
plt.plot(filtered_ecg, 'b-', linewidth=1, label='filtered_ecg')
plt.legend(loc='best')
plt.show()

## FILTRO FIR 2
## Usando la herramienta pyFDA y teniendo en cuenta que se quiere
## conservar la morfologia de la señal, se diseño un filtro FIR
## con el metodo Windowed FIR.

Fs  = 1000  # 1 KHz
Fpb = 0.001 # 1 Hz
Fsb = 0.045 # 45 Hz
Apb = 0.5   # dB
Asb = 30    # dB

# Número de polos y ceros 25
a = [0.001218571276082581,
0.003678060597291054,
0.007562266159509068,
0.012935463457197947,
0.0197241513780876,
0.027712653784719345,
0.036553646415441954,
0.045793017012035836,
0.054906834300512526,
0.06334679104328907,
0.07058946646197799,
0.07618424832905003,
0.07979482978480504,
0.07979482978480504,
0.07618424832905003,
0.07058946646197799,
0.06334679104328907,
0.05490683430051254,
0.045793017012035836,
0.03655364641544197,
0.027712653784719345,
0.019724151378087605,
0.012935463457197947,
0.007562266159509068,
0.003678060597291054,
0.0012185712760825836]

b = np.zeros(len(a))
b[0] = 1

ww, hh = sig.freqz(np.array(a), 1)
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='FIR')

plt.title('Filtro FIR 2')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

filtered_ecg = signal.filtfilt(a,b,ecg_signal)
plt.plot(ecg_signal, 'k-', label='ecg_signal')
plt.plot(filtered_ecg, 'b-', linewidth=1, label='filtered_ecg')
plt.legend(loc='best')
plt.show()
# Out:
# Espectro de la señal

# %%
## FILTRO IIR 1
## Usando la herramienta pyFDA y teniendo en cuenta que se quiere
## conservar la morfologia de la señal, se diseño un filtro IIR
## con el metodo Bessel.

Fs  = 1000  # 1 KHz
Fpb = 0.001 # 1 Hz
Fsb = 0.045 # 45 Hz
Apb = 0.5   # dB
Asb = 30    # dB

a = [0.02017, 0.02017]

b = [1, -0.9597] 

ww, hh = sig.freqz(np.array(a), np.array(b))
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='IIR')

plt.title('Filtro IIR 1')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

filtered_ecg = signal.filtfilt(a,b,ecg_signal)
plt.plot(ecg_signal, 'k-', label='ecg_signal')
plt.plot(filtered_ecg, 'b-', linewidth=1, label='filtered_ecg')
plt.legend(loc='best')
plt.show()

## FILTRO IIR 2
## Usando la herramienta pyFDA y teniendo en cuenta que se quiere
## conservar la morfologia de la señal, se diseño un filtro IIR
## con el metodo Butterworth.

a = [0.005648,
     0.0113,
     0.005648]

b = [1,
     -1.734,
     0.7568]
    
ww, hh = sig.freqz(np.array(a), np.array(b))
ww = ww / np.pi

plt.figure(1)
plt.plot(ww, 20 * np.log10(abs(hh)), label='IIR')

plt.title('Filtro IIR 2')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()

filtered_ecg = signal.filtfilt(a,b,ecg_signal)
plt.plot(ecg_signal, 'k-', label='ecg_signal')
plt.plot(filtered_ecg, 'b-', linewidth=1, label='filtered_ecg')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# d) Evalúe el rendimiento de los filtros que haya diseñado:
#
#  1. Verifique que filtra las señales interferentes
#  2. Verifique que es inocuo en las zonas donde no hay interferentes

# %%
## Graficas anteriores en el diseño del filtro.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Al realizarse varias pruebas y teniendo en cuenta la morfología de la señal para identificar partes de la señal como:
#
# <ul>
# <li>Onda P: Despolarización atrial</li>
# <li>Onda QRS: Despolarización ventricular</li>
# <li>Onda ST: Repolarización ventricular</li>
# <li>Onda T: Repolarización ventricular</li>
# </ul>
#
# Se considero que un filtro FIR elimina altas frecuencias indeseables sin  modificar de una forma agresiva la señal. Tambien el segundo filtro IIR diseñado tiene un buena restapuesta atenuando un poco la parte de la señal QRS pero eliminando el ruido de alta frecuencia.
#
# <img src="http://www.ecografiacardiaca.com/wp-content/uploads/2016/01/fisic-elec-1-copia.jpg"></img>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Utilice las siguientes metodologías <b>no lineales</b> de estimación-substracción para la remoción de la interferencia de línea de base, y compare con las técnicas lineales del punto anterior en las mismas regiones. Luego discuta las ventajas y desventajas de cada técnica.
# </div>

# %% [markdown]
# a) Estimación del movimiento de línea de base a partir del filtrado de mediana. A partir de la siguiente estimación del movimiento de línea de base
#
# $$ \hat{b} = \mathop{med}_{600} \{ \mathop{med}_{200} \{s\} \} $$
#
# Donde $s$ representa la señal de ECG a partir de la que estimamos el movimiento de la línea de base $ \hat{b}$. El operador $\mathop{med}_{200}$ calcula muestra a muestra la mediana en los 200 ms previos a la muestra actual. Luego dicha estimación la substraemos para estimar la actividad eléctrica cardíaca $\hat{x}$
#
# $$ \hat{x} = s - \hat{b} $$

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la implementación del <a href="https://docs.scipy.org/doc/scipy/reference/tutorial/signal.html#median-filter">filtro de mediana provista en <b>scipy.signal</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# b) Estimación del movimiento de línea de base a partir de los segmentos isoeléctricos de cada latido. A partir de las detecciones provistas, puede estimar aproximadamente el nivel isoeléctrico, es decir el momento donde la actividad eléctrica cardíaca es **nula**. El intervalo entre la onda P y Q, es un buen momento para estimar las características de las señales interferentes que originan el movimiento de la línea de base.
#
# <img src="./pq.png" align="center" width="80%" />
#
# Para la localización del segmento PQ puede valerse de la localización de cada latido (líneas rojas verticales) y a partir de la misma, anticipar un tiempo adecuado de manera tal de no incluir la onda P ni Q. Puede ayudarse con el latido promedio de un latido normal para establecer dicho intervalo.
#
# Recuerde que la señal de línea de base debe estar muestreada a la misma frecuencia que el ECG, por lo que debería remuestrear dicha señal (puede usar la función de interpolación spline para ello).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la función de interpolación <a href="https://docs.scipy.org/doc/scipy-0.18.1/reference/generated/scipy.interpolate.CubicSpline.html">spline <b>scipy.interpolate.CubicSpline</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>6)</b> Para la señal de ECG provista junto con este documento, aplique el concepto de <b>filtro adaptado</b> y otras técnicas de filtrado digital para diseñar un detector de latidos. Los patrones provistos son:
#
# </div>

# %% [markdown]
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en <a href="http://en.wikipedia.org/wiki/Matched_filter">Wikipedia</a>, o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %%
import scipy.io as sio

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# para listar las variables que hay en el archivo
#io.whosmat('ECG_TP4.mat')
mat_struct = sio.loadmat('./ECG_TP4.mat')

ecg_one_lead = vertical_flaten(mat_struct['ecg_lead'])
N = len(ecg_one_lead)

hb_1 = vertical_flaten(mat_struct['heartbeat_pattern1'])

plt.figure(1)
plt.plot(ecg_one_lead[5000:12000])

plt.figure(2)
plt.plot(hb_1)

# %% [markdown]
# a) Explique conceptualmente cómo podría realizar un detector de latidos con la señal resultante del filtro adaptado. Discuta la utilidad y limitaciones de este método.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
#
#    b) Realice la detección de los latidos, comparando las detecciones obtenidas con las que se incluyen en la variable **qrs_detections**. Proponga alguna métrica para cuantificar las diferencias.

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
