# %% [markdown]
# <img src="./fiuba.jpg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 1
# #### Ericson Estupiñan
#
# ***
# ## Muestreo de señales - Fourier

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Se busca realizar una librería en Python que nos permita obtener $N$ muestras de las siguientes señales de período $T_0=1/f_0$, muestreadas a una frecuencia $f_s$ :
#
# </div>

# %% [markdown]
# + **Senoidal**
#
# > $s(k)=A_0.sin((2\pi.f_0 + \phi_0).k/f_s),\space\space \forall k \in \Bbb{Z} \wedge k \in (0, N-1)$
#
# + __Ruido__ incorrelado de distribución Gaussiana y parámetros $\mu$ y $\sigma^2$
#
# ***
#
# + (Opcional) __Cuadrada__ con ciclo de actividad $d \in (0,1)$
#
# > $s(k)=A_0,\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=-A_0,\space \forall k \in (N.d, N-1)$
#
# + (Opcional) __Triangular__ con punto de simetría $d \in (0,1)$ y coeficientes $a_{ij} \in \Bbb{R}$
#
# > $s(k)=a_{11}.k/f_s+a_{12},\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=a_{21}.k/f_s+a_{22},\space \forall k \in (N.d, N-1)$

# %% [markdown]
# Es decir que se podría invocar la señal que genere la senoidal de la siguiente manera:

# %% [markdown]
# a) Genere las gráficas asociadas a las siguientes señales de ejemplo para corroborar el correcto funcionamiento de las funciones. Para la presentación de las mismas, tome como referencia la presentación de la siguiente señal respecto a:
#
# * etiquetas indicando cada eje con sus respectivas unidades
# * leyendas indicando cada trazo o color qué representa
# * título de la figura que explique lo que se pretende visualizar
#
#
# <img src="./fig_ejemplo.svg" align="center" width="100%" />
# <img src="./fig_ejemplo2.svg" align="center" width="70%" />

# %%
# Módulos para Jupyter
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib as mpl

#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

import matplotlib.pyplot as plt

def generador_senoidal (fs, f0, N, a0=1, p0=0):
    
    """ 
    
    brief:  Generador de señales senoidal, con argumentos
    
    fs:     frecuencia de muestreo de la señal [Hz]
    N:      cantidad de muestras de la señal a generar
    f0:     frecuencia de la senoidal [Hz]
    a0:     amplitud pico de la señal [V]
    p0:     fase de la señal sinusoidal [rad]
    
    como resultado la señal devuelve:
    
    signal: senoidal evaluada en cada instante 
    tt:     base de tiempo de la señal
    """    
    
    # comienzo de la función
    ts = 1/fs # tiempo de muestreo
    df = fs/N # resolución espectral 
    
    # grilla de sampleo temporal
    tt = np.linspace(0, (N-1)*ts, N).flatten()
    
    # grilla de sampleo frecuencial
    ff = np.linspace(0, (N-1)*df, N).flatten()

    # Concatenación de matrices:
    # guardaremos las señales creadas al ir poblando la siguiente matriz vacía
    signal = np.array([], dtype=np.float).reshape(N,0)
    
    # prestar atención que las tuplas dentro de los diccionarios también pueden direccionarse mediante "ii"
    aux = a0 * np.sin( 2*np.pi*f0*tt + p0)
    # para concatenar horizontalmente es necesario cuidar que tengan iguales FILAS
    signal = np.hstack([signal, aux.reshape(N,1)] )
    
    # fin de la función
    
    return tt, signal

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Insertar aquí el código para inicializar tu notebook
########################################################

# %%
# NO modifiques este bloque
############################

N  = 1000 # muestras
fs = 1000 # Hz

# %%
##################
# a.1) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = 10   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tt,x = generador_senoidal(fs, f0, N, a0, p0);

#%% Presentación gráfica de los resultados
    
plt.figure(1)
line_hdls = plt.plot(tt, x)
plt.title('Señal: Senoidal')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

# este tipo de sintaxis es *MUY* de Python
axes_hdl.legend(line_hdls, "sig_type['descripcion']", loc='upper right')

plt.show()

# %% [markdown]
# ¿Podría inferir la frecuencia de la senoidal a.1 a partir de su representación temporal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> SI, se puede contar los ciclos en un periodo de 1 segundo.<br>
# </div>

# %%
##################
# a.2) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = fs/2   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tt,x = generador_senoidal(fs, f0, N, a0, p0);

#%% Presentación gráfica de los resultados
    
plt.figure(1)
line_hdls = plt.plot(tt, x)
plt.title('Señal: Senoidal')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

# este tipo de sintaxis es *MUY* de Python
axes_hdl.legend(line_hdls, "sig_type['descripcion']", loc='upper right')

plt.show()

# %%
##################
# a.3) Senoidal #
#################

a0 = 1       # Volts
p0 = np.pi/2 # radianes
f0 = fs/2    # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tt, x = generador_senoidal(fs, f0, N, a0, p0);

#%% Presentación gráfica de los resultados
    
plt.figure(1)
line_hdls = plt.plot(tt, x)
plt.title('Señal: Senoidal')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

# este tipo de sintaxis es *MUY* de Python
axes_hdl.legend(line_hdls, "sig_type['descripcion']", loc='upper right')

plt.show()

# %% [markdown]
# ¿Y para los casos **a.2** y **a.3** podría conocer los parámetros de la senoidal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> NO, aun que se muestrea a la frecuencia de nyquist no es suficiente en los casos de estudio para identificar la señal.
# </div>

# %% [markdown]
# ¿A qué se debe?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Esto se debe la frecuencia de muestreo es justo la frecuencia de Nyquist y solo se tendrian dos muestras por ciclo las cuales en una señal senoidal pueden esta en los valores en los que la señal es cero.
# </div>

# %%
##################
# a.4) Senoidal #
#################

a0 = 1     # Volts
p0 = 0     # radianes
f0 = fs+10 # Hz

print("fs :", fs)
print("f0 :", f0)

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tt,x = generador_senoidal(fs, f0, N, a0, p0);

#%% Presentación gráfica de los resultados
    
plt.figure(1)
line_hdls = plt.plot(tt, x)
plt.title('Señal: Senoidal')
plt.xlabel('tiempo [segundos]')
plt.ylabel('Amplitud [V]')
plt.grid(which='both', axis='both')

# presentar una leyenda para cada tipo de señal
axes_hdl = plt.gca()

# este tipo de sintaxis es *MUY* de Python
axes_hdl.legend(line_hdls, "sig_type['descripcion']", loc='upper right')

plt.show()
# Out:
# fs : 1024
# f0 : 1034

# %% [markdown]
# ¿Es posible diferenciar **a.1** de **a.4** a partir de las gráficas?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> La frecuencia de muestreo no se puede aplicar a la señal, ya que esta es inferior a la frecuencia central de la señal a muestrear.
# </div>

# %% [markdown]
# ¿En caso que no, qué solución podría implementar para evitar dicha ambigüedad?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Para evitar este efecto es necesario que la frecuencia de muestreo sea mayor superior al dobre de la frecuencia.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.a)</b> (Opcional) Implemente un algoritmo que calcule la transformada discreta de Fourier (DFT). Utilice las funciones generadoras de señales de 1) para evaluar y ejemplificar su funcionamiento.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.b)</b> (Opcional) Compare el tiempo de ejecución de la DFT implementada en con la **FFT** (implementada en **scipy.signal**) en función del tamaño de la señal N. Grafique el tiempo de ejecución de ambos casos en función de N.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Utilice el módulo **timeit** para medir el tiempo transcurrido.
# </div>

# %%
import timeit
from scipy.fftpack import fft

the_start = timeit.timeit()

a0 = 1 # Volts
p0 = 0 # radianes
f0 = 100   # Hz

ts = 1/fs

tt = np.linspace(0, (N-1)*ts, N)
y = 1 * np.sin( 2*np.pi*f0*tt)

yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*ts), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

the_end = timeit.timeit()
print(the_start - the_end)
# Out:
# 0.0012062700006936211

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
from pandas import DataFrame
from IPython.display import HTML
import scipy.fftpack as sc
import time

#######################################
# Algorithm                           #
#######################################
def dft(x):
    t = []
    N = len(x)
    for k in range(N):
        a = 0
        for n in range(N):
            a += x[n]*np.exp(-2j*np.pi*k*n*(1/N))
        t.append(a)
    return t


# SAMPLES
SAMPLES = [16,
           32,
           64,
           128,
           256,
           512,
           1024,
           2048]

fs = 1024 # Hz
a0 = 1    # Volts
p0 = 0    # radianes
f0 = 10   # Hz


#######################################
# Tu simulación que genere resultados #
#######################################
w, h = 2, len(SAMPLES) + 1;
rest = [[0 for x in range(w)] for y in range(h)]

rest[0][0] = 'Algorithm'
i = 1
for N in SAMPLES:
    tt,x = generador_senoidal(fs, f0, N, a0, p0);
    the_start = time.time()
    spectrum = (2/N)*np.abs(dft(x))
    the_end = time.time()
    rest[i][0] = str('%.5f'%(np.abs(the_start - the_end)))
    i += 1


rest[0][1] = 'scipy.fftpack'
i = 1
for N in SAMPLES:
    tt,x = generador_senoidal(fs, f0, N, a0, p0);
    the_start = time.time()
    spectrum = (2/N)*np.abs(sc.fft(x))
    the_end = time.time()
    rest[i][1] = str('%.5f'%(np.abs(the_start - the_end)))
    i += 1


df = DataFrame(rest, columns=['tiempo transcurrido (s)', 'tiempo transcurrido (s)'],
               index=['Tamaño de la señal N', 
                      16, 
                      32, 
                      64, 
                      128,
                      256,
                      512,
                      1024,
                      2048
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tiempo transcurrido (s)</th>
#       <th>tiempo transcurrido (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tamaño de la señal N</th>
#       <td>Algorithm</td>
#       <td>scipy.fftpack</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.00290</td>
#       <td>0.00002</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>0.00806</td>
#       <td>0.00001</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>0.02201</td>
#       <td>0.00001</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>0.12784</td>
#       <td>0.00001</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>0.42153</td>
#       <td>0.00001</td>
#     </tr>
#     <tr>
#       <th>512</th>
#       <td>1.21223</td>
#       <td>0.00002</td>
#     </tr>
#     <tr>
#       <th>1024</th>
#       <td>5.35689</td>
#       <td>0.00002</td>
#     </tr>
#     <tr>
#       <th>2048</th>
#       <td>17.28637</td>
#       <td>0.00004</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.a)</b> Verifique el efecto del leakage para una senoidal de $f_0 = f_S/4 + f_D$ siendo $f_D = (0.01,\, 0.25,\, 0.5)$, es decir una frecuencia de desintonía respecto al bin $f_S/4$.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
# Function get Frequency
def getFreq(signal, Fs, N, nextFreq):
    spectrum = (2/N)*np.abs(sc.fft(signal))
    half = spectrum[:N//2]
    freqs = np.linspace(0.0, Fs/2, N/2)
    return freqs[np.argmax(half) + nextFreq], half[np.argmax(half)+nextFreq] 


def sumRestFreq(signal, Fs, N):
    spectrum = (2/N)*np.abs(sc.fft(signal))
    half = spectrum[:N//2]
    freqs = np.linspace(0.0, Fs/2, N/2)
    freq_0 = np.argmax(half);
    half = np.delete(half, freq_0, 0)
    half = np.power(half, 2)
    return half.sum();


N  = 1024   # muestras elegir potencias de 2 por temas de la memoria
Fs = 1024   # Hz

Ts   = 1/Fs 
Tadq = N*Ts # Tiempo de adquisicion N/Fs

t = np.linspace(0.0, (N-1)*Ts, N)
    
# VAR FREQ
VAR_FREQ = [0, 0.01, 0.25, 0.5]
w, h = 3, len(VAR_FREQ);
rest = [[0 for x in range(w)] for y in range(h)]

i = 0
for varf in VAR_FREQ:
    Fsignal = Fs/4 + varf # Hz
    ## senoidal 
    signal_sin = np.sin(2*np.pi*Fsignal*t);
    f0, v = getFreq(signal_sin, Fs, N, 0)
    print(f0)   
    
    
    
    rest[i][0] = '%.5f'%v
    f0, v = getFreq(signal_sin, Fs, N, 1)

    rest[i][1] = '%.5f'%v
    rest[i][2] = '%.5f'%sumRestFreq(signal_sin, Fs, N)
    i = i + 1 

print(rest)

#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$ \lvert X(f_0) \lvert$', '$ \lvert X(f_0+1) \lvert $', '$\sum_{i=F} \lvert X(f_i) \lvert ^2 $'], 
                   ['',                        '',                           '$F:f \neq f_0$'], 
                  [rest[0][0], rest[0][1], rest[0][2]], # <-- acá debería haber numeritos :)
                  [rest[1][0], rest[1][1], rest[1][2]], # <-- acá debería haber numeritos :)
                  [rest[2][0], rest[2][1], rest[2][2]], # <-- acá debería haber numeritos :)
                  [rest[3][0], rest[3][1], rest[3][2]]  # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['Frecuencia central', 'Primer adyacente', 'Resto de frecuencias'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '$f_S/4$', 
                      '$f_S/4+0.01$', 
                      '$f_S/4+0.25$', 
                      '$f_S/4+0.5$'])
HTML(df.to_html())
# Out:
# 256.5009784735812
# 256.5009784735812
# 256.5009784735812
# 257.5029354207436
# [['1.00000', '0.00000', '0.00000'], ['0.99983', '0.01010', '0.00033'], ['0.89963', '0.30080', '0.18969'], ['0.63662', '0.21221', '0.59471']]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Frecuencia central</th>
#       <th>Primer adyacente</th>
#       <th>Resto de frecuencias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$ \lvert X(f_0) \lvert$</td>
#       <td>$ \lvert X(f_0+1) \lvert $</td>
#       <td>$\sum_{i=F} \lvert X(f_i) \lvert ^2 $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$F:f \neq f_0$</td>
#     </tr>
#     <tr>
#       <th>$f_S/4$</th>
#       <td>1.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.01$</th>
#       <td>0.99983</td>
#       <td>0.01010</td>
#       <td>0.00033</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.25$</th>
#       <td>0.89963</td>
#       <td>0.30080</td>
#       <td>0.18969</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.5$</th>
#       <td>0.63662</td>
#       <td>0.21221</td>
#       <td>0.59471</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.b)</b> Verifique qué ocurre si a la señal de $f_0 = f_S/4 + 0.5$ se le agregan ceros para prolongar su duración. Es decir si la señal tiene N muestras, agregue $M_j$ ceros siendo $M_j = ( \frac{N}{10},\, N,\, 10N)$.
# </div>

# %%
N  = 1024   # muestras elegir potencias de 2 por temas de la memoria
M  = round(10*N)  # ceros

Fs = 1024   # Hz

Ts   = 1/Fs 
Tadq = N*Ts # Tiempo de adquisicion N/Fs

Fsignal = Fs/4 # Hz  256 + 0.5

t = np.linspace(0.0, ((N+M)-1)*Ts, (N+M))

## senoidal 
signal_sin = np.zeros(N+M)
signal_sin[:N] = np.sin(2*np.pi*Fsignal*t[:N]);

f0, v = getFreq(signal_sin, Fs, N+M, 0)
print(f0, v)

yf = fft(signal_sin)
xf = np.linspace(0.0, 1.0/(2.0*Ts), (N+M)//2)

import matplotlib.pyplot as plt
plt.stem(xf, 2.0/(N+M) * np.abs(yf[0:(N+M)//2]))
plt.grid()
plt.show()
# Out:
# 256.0454626176523 0.09090909090909091

# %% [markdown]
# **3.c)** ¿Ha variado la resolución espectral en los casos de 3.b?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Si varia, ya que esta es equivalente a  1/N*Ts o Fs/N y el número de muestras N se ingremento y se agregó ceros a la señal.
# </div>

# %% [markdown]
# **3.d)** ¿Cuál es el efecto que se produce en cada caso? Esta técnica se conoce como Zero padding.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Aunque el efecto de 'spectral leakage' sigue presente, la identificacion de la frecuencia centrel es más facil y más precisa.
# </div>

# %% [markdown]
# **3.e)** Analice cuál es la frecuencia  $\hat{f}_0 = \mathop{arg\ max}_f \{\lvert X(f) \rvert \}$ a la que ocurre el máximo del espectro y en cuánto difiere de $f_0$ en términos porcentuales.

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

N  = 1024   # muestras elegir potencias de 2 por temas de la memoria

VAR_N = [0, N/10, N, 10*N]

w, h = 1, len(VAR_N)
rest = [[0 for x in range(w)] for y in range(h)]

i = 0
for j in VAR_N:
    M  = round(j)  # ceros
    Fs = 1024   # Hz
    Ts   = 1/Fs 
    Tadq = N*Ts # Tiempo de adquisicion N/Fs

    Fsignal = Fs/4 + 0.5 # Hz  256 + 0.5
    t = np.linspace(0.0, ((N+M)-1)*Ts, (N+M))

    ## senoidal 
    signal_sin = np.zeros(N+M)
    signal_sin[:N] = np.sin(2*np.pi*Fsignal*t[:N]);
    f0, v = getFreq(signal_sin, Fs, N+M, 0)
    rest[i] = '%.5f'%v
    i = i + 1

tus_resultados = [rest[0], # <-- acá debería haber numeritos :)
                  rest[1], # <-- acá debería haber numeritos :)
                  rest[2], # <-- acá debería haber numeritos :)
                  rest[3] # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$e_\%$'],
               index=['0',
                      '$N/10$', 
                      '$N$', 
                      '$10N$'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$e_\%$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.63662</td>
#     </tr>
#     <tr>
#       <th>$N/10$</th>
#       <td>0.90635</td>
#     </tr>
#     <tr>
#       <th>$N$</th>
#       <td>0.50000</td>
#     </tr>
#     <tr>
#       <th>$10N$</th>
#       <td>0.09060</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b>
# Para cada señal propuesta complete los valores que se indican en las siguientes consignas.
# </div>

# %% [markdown]
# + En la tabla de resultados de cada inciso, en la fila indicada con **predicción** responda conceptualmente qué contenido espectral debería obtener tras evaluar su FFT (sin realizar ninguna simulación).
# + Calcule su espectro y discuta la predicción con los resultados obtenidos de la **simulación**. Intente discutir las diferencias si las hubiera en las respuestas de cada inciso.
# + Preste especial atención en su discusión a:
#   * La energía total de la señal
#   * La energía del tono en particular
#   * La localización del tono en el espectro
# + Siga las indicaciones particulares para cada señal.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Las siguientes señales pueden generarse a partir de una senoidal *patrón* siguiendo las consignas de la derecha.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./1.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.a) Senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./2.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.b) **1 solo ciclo** de la misma senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observe el resultado y compare sus resultados con el punto anterior. ¿Qué ha cambiado? ¿Cuánto vale la energía de un solo ciclo de senoidal respecto al caso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./3.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.c) 1 solo ciclo de la misma senoidal
# 				de energía normalizada y frecuencia $f_0 = 9 \cdot f_S/N$ **pero demorado un tiempo igual a dos ciclos**. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# En este caso, ¿Qué ha cambiado respecto al anterior? ¿Cómo se manifiesta en el dominio frecuencial?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./4.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.d) 1 solo ciclo de la misma senoidal utilizada hasta ahora, y otro ciclo de idénticas características pero de $f_1 = 8 \cdot f_S/N$ y demorado aproximadamente como se observa a la izquierda. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Puede localizar ambas componentes en este espectro? ¿Cómo lo haría?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./5.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.e) Idéntico al caso anterior salvo que se invierte la ocurrencia de las señales. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿ha cambiado el espectro respecto al caso anterior? ¿Si solo dispone del espectro, puede decir cuál ha ocurrido antes? ¿Resulta útil el análisis de espectral mediante la transformada de Fourier en este caso?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./6.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.f) Arme una señal como la que se muestra a la izquierda, concatenando 3 ciclos de $f_0 = 9 \cdot f_S/N$.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con la señal donde los 9 ciclos estaban presentes? ¿Y respecto a la que solo había 1 ciclo?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./7.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.g) Idem anterior, pero cada ciclo con amplitudes (1, 5, 3).</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./8.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.h) Idem patrón anterior, pero repetido 3 veces.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior? ¿Y respecto al que estaban los 9 ciclos presentes pero con la misma amplitud?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./9.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.i) En este caso genere un ciclo de $f_0 = 9 \cdot f_S/N$, y seguido otro ciclo pero desfasado $\pi$ radianes.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  ['', '', '']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el que estaba un solo ciclo presente?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# Luego de realizar la experimentación y observando los resultados obtenidos discuta si es fiable o no medir en el dominio de Fourier, por medio de la FFT los siguientes aspectos de una señal:
#
#     • Energía
#     • Contenido espectral
#     • Energía de un determinado ancho de banda o componente espectral
#     • Localización temporal de un determinado componente espectral.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b>
# Simule el efecto de cuantizar una señal continua en el tiempo mediante un conversor analógico digital (ADC).
# </div>

# %% [markdown]
# Para ello analice señales determinísticas, por ejemplo una senoidal de **energía normalizada** y frecuencia $f_0$, y otras que varíen de forma más aleatoria y por lo tanto, representativa de una señal real, por ejemplo añadiendo ruido. Es decir que la señal *real* simulada será
#
# $$s_R = s + n$$
#
# donde la señal $n$ debe tener una energía de $1/10$.
#
# Puede simular una señal continua (aproximadamente para los fines prácticos), mediante una señal muestreada a una $f^1_S$ muy alta en comparación con las $f_S$  que quiere estudiar, y un tipo de dato de doble precisión (double o float de 64 bits). De esta manera se asegura una grilla de cuantización (en tiempo y amplitud) mucho más densa que la que se va a simular. Se pide cuantizar a palabras de 4, 8 y 16 bits, obteniendo
#
# $$ s_Q = \mathop{Q}_i \{s_R\} \quad i \in (4, 8, 16) $$
#
# Siendo $\mathop{Q}_i$ la función **no lineal** responsable de la cuantización a *i-* bits de la señal real $s_R$. Describa el ruido de cuantización
#
# $$ e = s_Q - s_R$$
#
# para las 3 situaciones antedichas siguiendo las siguientes consignas.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.a)</b>
# La señal temporal $e$ y su espectro $E$.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$' ], 
                   ['',                                             '',                                             ''                              ], 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía total Q', 'Energía total $e$'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía total Q</th>
#       <th>Energía total $e$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.b)</b> El histograma de la señal $e_i$ para cada tamaño de palabra.
# </div>

# %%
#####################################
# Tu simulación que genere gráficas #
#####################################

# %% [markdown]
# ¿Qué información podemos obtener de esta forma de analizar la señal $e_i$?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.c)</b> Una descripción de la señal $e_i$, por medio del **valor medio**, su valor **RMS** y su energía **energía**
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Valor medio', 'RMS', 'Energía'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor medio</th>
#       <th>RMS</th>
#       <th>Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.d)</b> Una descripción **estadística** de la señal $e_i$, por medio de su **media**, su **desvío estándard** y su energía **varianza**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Media', 'Desvío estándard', 'Varianza'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Media</th>
#       <th>Desvío estándard</th>
#       <th>Varianza</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Discutir las similitudes y diferencias con los parámetros calculados en **c)** y **d)**.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>
